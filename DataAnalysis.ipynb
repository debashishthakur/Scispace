# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
df = pd.read_csv("E:/Scispace/dataset.csv")
df.head()
# Out:
#              Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 0  01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90    93.3
# 1  01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28    93.4
# 2  01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31    93.9
# 3  01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07    94.2
# 4  01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04    94.1
#
#    VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 0          3.33          3.11          0.22       1.94             3.12
# 1          3.23          3.02          0.21       1.89             3.03
# 2          3.21          3.01          0.20       1.88             3.02
# 3          3.26          3.07          0.19       1.92             3.08
# 4          3.27          3.08          0.19       1.92             3.09
#
#    rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 0       1307.75      1.03           1.75     152.3
# 1       1309.80      0.72           1.50     136.1
# 2       1310.24      0.19           0.63     171.6
# 3       1309.19      0.34           0.50     198.0
# 4       1309.00      0.32           0.63     214.3

# %%
df_1 = df[5::12]

# %%
temperature_counts = df_1["T (degC)"].value_counts()
print(temperature_counts)
# Out:
# T (degC)
#  8.86     31
#  5.27     30
#  14.87    28
#  4.03     28
#  5.42     27
#           ..
# -10.51     1
#  28.07     1
# -11.74     1
# -12.64     1
# -8.01      1
# Name: count, Length: 4207, dtype: int64

# %%
df1 = df[11::12]
df1
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 11      01.01.2009 02:00:00    996.62     -8.88    264.54        -9.77
# 23      01.01.2009 04:00:00    996.99     -9.05    264.34       -10.02
# 35      01.01.2009 06:00:00    997.71     -9.67    263.66       -10.62
# 47      01.01.2009 08:00:00    999.17     -8.10    265.12        -9.05
# 59      01.01.2009 10:00:00   1000.27     -7.04    266.10        -8.17
# ...                     ...       ...       ...       ...          ...
# 420491  31.12.2016 14:10:00   1003.25      4.15    277.05        -3.76
# 420503  31.12.2016 16:10:00   1002.54      2.44    275.40        -4.39
# 420515  31.12.2016 18:10:00   1002.27     -0.42    272.56        -4.92
# 420527  31.12.2016 20:10:00   1001.40     -1.40    271.66        -6.84
# 420539  31.12.2016 22:10:00   1000.65     -2.89    270.22        -7.15
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# 11       93.20          3.12          2.90          0.21       1.81
# 23       92.60          3.07          2.85          0.23       1.78
# 35       92.70          2.93          2.71          0.21       1.69
# 47       92.80          3.31          3.07          0.24       1.92
# 59       91.60          3.60          3.30          0.30       2.05
# ...        ...           ...           ...           ...        ...
# 420491   56.20          8.22          4.62          3.60       2.87
# 420503   60.50          7.28          4.41          2.88       2.74
# 420515   71.50          5.92          4.23          1.69       2.63
# 420527   66.29          5.51          3.65          1.86       2.27
# 420539   72.30          4.93          3.57          1.37       2.22
#
#         H2OC (mmol/mol)  rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 11                 2.91       1312.25      0.25           0.63     190.3
# 23                 2.85       1313.61      0.10           0.38     240.0
# 35                 2.72       1317.71      0.05           0.50     146.0
# 47                 3.08       1311.65      0.72           1.25     213.9
# 59                 3.29       1307.76      1.45           3.00     292.6
# ...                 ...           ...       ...            ...       ...
# 420491             4.61       1258.09      0.58           1.32     231.0
# 420503             4.40       1265.12      0.46           1.08     177.2
# 420515             4.22       1278.14      0.44           1.00     232.8
# 420527             3.65       1281.87      1.02           1.92     225.4
# 420539             3.57       1288.03      0.35           0.68     216.7
#
# [35045 rows x 15 columns]

# %%
date_time = pd.to_datetime(df1.pop('Date Time'), format="%d.%m.%Y %H:%M:%S")

# %%
df1
# Out:
#         p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# 11        996.62     -8.88    264.54        -9.77   93.20          3.12
# 23        996.99     -9.05    264.34       -10.02   92.60          3.07
# 35        997.71     -9.67    263.66       -10.62   92.70          2.93
# 47        999.17     -8.10    265.12        -9.05   92.80          3.31
# 59       1000.27     -7.04    266.10        -8.17   91.60          3.60
# ...          ...       ...       ...          ...     ...           ...
# 420491   1003.25      4.15    277.05        -3.76   56.20          8.22
# 420503   1002.54      2.44    275.40        -4.39   60.50          7.28
# 420515   1002.27     -0.42    272.56        -4.92   71.50          5.92
# 420527   1001.40     -1.40    271.66        -6.84   66.29          5.51
# 420539   1000.65     -2.89    270.22        -7.15   72.30          4.93
#
#         VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# 11              2.90          0.21       1.81             2.91       1312.25
# 23              2.85          0.23       1.78             2.85       1313.61
# 35              2.71          0.21       1.69             2.72       1317.71
# 47              3.07          0.24       1.92             3.08       1311.65
# 59              3.30          0.30       2.05             3.29       1307.76
# ...              ...           ...        ...              ...           ...
# 420491          4.62          3.60       2.87             4.61       1258.09
# 420503          4.41          2.88       2.74             4.40       1265.12
# 420515          4.23          1.69       2.63             4.22       1278.14
# 420527          3.65          1.86       2.27             3.65       1281.87
# 420539          3.57          1.37       2.22             3.57       1288.03
#
#         wv (m/s)  max. wv (m/s)  wd (deg)
# 11          0.25           0.63     190.3
# 23          0.10           0.38     240.0
# 35          0.05           0.50     146.0
# 47          0.72           1.25     213.9
# 59          1.45           3.00     292.6
# ...          ...            ...       ...
# 420491      0.58           1.32     231.0
# 420503      0.46           1.08     177.2
# 420515      0.44           1.00     232.8
# 420527      1.02           1.92     225.4
# 420539      0.35           0.68     216.7
#
# [35045 rows x 14 columns]

# %%
plot_cols = ['T (degC)','p (mbar)']
plot_features = df[plot_cols]
fig = px.line(df1, x=date_time,y='T (degC)')
fig.show()
# Out:
# C:\Users\DEBASHISH THAKUR\AppData\Local\Programs\Python\Python311\Lib\site-packages\_plotly_utils\basevalidators.py:105: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
# <div>                            <div id="e62c4374-b843-4786-9e40-53b86c9f3e7c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e62c4374-b843-4786-9e40-53b86c9f3e7c")) {                    Plotly.newPlot(                        "e62c4374-b843-4786-9e40-53b86c9f3e7c",                        [{"hovertemplate":"x=%{x}\u003cbr\u003eT (degC)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2009-01-01T02:00:00","2009-01-01T04:00:00","2009-01-01T06:00:00","2009-01-01T08:00:00","2009-01-01T10:00:00","2009-01-01T12:00:00","2009-01-01T14:00:00","2009-01-01T16:00:00","2009-01-01T18:00:00","2009-01-01T20:00:00","2009-01-01T22:00:00","2009-01-02T00:00:00","2009-01-02T02:00:00","2009-01-02T04:00:00","2009-01-02T06:00:00","2009-01-02T08:00:00","2009-01-02T10:00:00","2009-01-02T12:00:00","2009-01-02T14:00:00","2009-01-02T16:00:00","2009-01-02T18:00:00","2009-01-02T20:00:00","2009-01-02T22:00:00","2009-01-03T00:00:00","2009-01-03T02:00:00","2009-01-03T04:00:00","2009-01-03T06:00:00","2009-01-03T08:00:00","2009-01-03T10:00:00","2009-01-03T12:00:00","2009-01-03T14:00:00","2009-01-03T16:00:00","2009-01-03T18:00:00","2009-01-03T20:00:00","2009-01-03T22:00:00","2009-01-04T00:00:00","2009-01-04T02:00:00","2009-01-04T04:00:00","2009-01-04T06:00:00","2009-01-04T08:00:00","2009-01-04T10:00:00","2009-01-04T12:00:00","2009-01-04T14:00:00","2009-01-04T16:00:00","2009-01-04T18:00:00","2009-01-04T20:00:00","2009-01-04T22:00:00","2009-01-05T00:00:00","2009-01-05T02:00:00","2009-01-05T04:00:00","2009-01-05T06:00:00","2009-01-05T08:00:00","2009-01-05T10:00:00","2009-01-05T12:00:00","2009-01-05T14:00:00","2009-01-05T16:00:00","2009-01-05T18:00:00","2009-01-05T20:00:00","2009-01-05T22:00:00","2009-01-06T00:00:00","2009-01-06T02:00:00","2009-01-06T04:00:00","2009-01-06T06:00:00","2009-01-06T08:00:00","2009-01-06T10:00:00","2009-01-06T12:00:00","2009-01-06T14:00:00","2009-01-06T16:00:00","2009-01-06T18:00:00","2009-01-06T20:00:00","2009-01-06T22:00:00","2009-01-07T00:00:00","2009-01-07T02:00:00","2009-01-07T04:00:00","2009-01-07T06:00:00","2009-01-07T08:00:00","2009-01-07T10:00:00","2009-01-07T12:00:00","2009-01-07T14:00:00","2009-01-07T16:00:00","2009-01-07T18:00:00","2009-01-07T20:00:00","2009-01-07T22:00:00","2009-01-08T00:00:00","2009-01-08T02:00:00","2009-01-08T04:00:00","2009-01-08T06:00:00","2009-01-08T08:00:00","2009-01-08T10:00:00","2009-01-08T12:00:00","2009-01-08T14:00:00","2009-01-08T16:00:00","2009-01-08T18:00:00","2009-01-08T20:00:00","2009-01-08T22:00:00","2009-01-09T00:00:00","2009-01-09T02:00:00","2009-01-09T04:00:00","2009-01-09T06:00:00","2009-01-09T08:00:00","2009-01-09T10:00:00","2009-01-09T12:00:00","2009-01-09T14:00:00","2009-01-09T16:00:00","2009-01-09T18:00:00","2009-01-09T20:00:00","2009-01-09T22:00:00","2009-01-10T00:00:00","2009-01-10T02:00:00","2009-01-10T04:00:00","2009-01-10T06:00:00","2009-01-10T08:00:00","2009-01-10T10:00:00","2009-01-10T12:00:00","2009-01-10T14:00:00","2009-01-10T16:00:00","2009-01-10T18:00:00","2009-01-10T20:00:00","2009-01-10T22:00:00","2009-01-11T00:00:00","2009-01-11T02:00:00","2009-01-11T04:00:00","2009-01-11T06:00:00","2009-01-11T08:00:00","2009-01-11T10:00:00","2009-01-11T12:00:00","2009-01-11T14:00:00","2009-01-11T16:00:00","2009-01-11T18:00:00","2009-01-11T20:00:00","2009-01-11T22:00:00","2009-01-12T00:00:00","2009-01-12T02:00:00","2009-01-12T04:00:00","2009-01-12T06:00:00","2009-01-12T08:00:00","2009-01-12T10:00:00","2009-01-12T12:00:00","2009-01-12T14:00:00","2009-01-12T16:00:00","2009-01-12T18:00:00","2009-01-12T20:00:00","2009-01-12T22:00:00","2009-01-13T00:00:00","2009-01-13T02:00:00","2009-01-13T04:00:00","2009-01-13T06:00:00","2009 ...
